# %%
#5585번

T = int(input())
count = 0

time_count = [300, 60, 10]

if(T % 10):
  print(-1)
else:
  for time in time_count:
      count = T // time 
      T %= time
      
      print(count)
# Out:
# 100
# 0
# 1
# 4
